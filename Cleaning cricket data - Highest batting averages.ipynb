# %%
#https://www.espncricinfo.com/records/highest-career-batting-average-282910

# %%
#import pandas as pd

# %%
import pandas as pd

# %%
#import csv file

# %%
df = pd.read_csv('Highest averages.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 63  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 64  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 65    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 66   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7  626+   6
# ...

# %%
# Change table headers

# %%
df = df.rename(columns = {'NO':'Not Outs', 'HS':'Highest Score', 'Ave': 'Averages', 'BF':'Balls Faced', 'SR': 'Strike Rate'})

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not Outs  Runs Highest Score  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996           334
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181           186
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485          269*
# 3     RG Pollock (SA)  1963-1970   23    41         4  2256           274
# 4     GA Headley (WI)  1930-1954   22    40         4  2190          270*
# ..                ...        ...  ...   ...       ...   ...           ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357           250
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265           277
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122           266
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748           232
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296           127
#
#     Averages Balls Faced Strike Rate  100  50   0    4s  6s
# ...

# %%
# Check null values

# %%
df.isnull().any()
# Out:
# Player           False
# Span             False
# Mat              False
# Inns             False
# Not Outs         False
# Runs             False
# Highest Score    False
# Averages         False
# Balls Faced       True
# Strike Rate       True
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# dtype: bool

# %%
df[df['Balls Faced'].isna()==1]
# Out:
#              Player       Span  Mat  Inns  Not Outs  Runs Highest Score  \
# 8    ED Weekes (WI)  1948-1958   48    81         5  4455           207
# 17  CL Walcott (WI)  1948-1960   44    74         7  3798           220
#
#     Averages Balls Faced Strike Rate  100  50  0    4s  6s
# 8      58.61         NaN         NaN   15  19  6  258+   2
# 17     56.68         NaN         NaN   15  14  1  107+  11

# %%
df['Balls Faced'] = df['Balls Faced'].fillna(0)

# %%
df['Strike Rate'] = df['Strike Rate'].fillna(0)

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not Outs  Runs Highest Score  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996           334
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181           186
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485          269*
# 3     RG Pollock (SA)  1963-1970   23    41         4  2256           274
# 4     GA Headley (WI)  1930-1954   22    40         4  2190          270*
# ..                ...        ...  ...   ...       ...   ...           ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357           250
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265           277
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122           266
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748           232
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296           127
#
#     Averages Balls Faced Strike Rate  100  50   0    4s  6s
# ...

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
#            Player       Span  Mat  Inns  Not Outs  Runs Highest Score  \
# 8  ED Weekes (WI)  1948-1958   48    81         5  4455           207
#
#    Averages Balls Faced Strike Rate  100  50  0    4s 6s
# 8     58.61           0           0   15  19  6  258+  2

# %%
# drop duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# Length: 67, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#             Player       Span  Mat  Inns  Not Outs  Runs Highest Score  \
# 12  GS Sobers (WI)  1954-1974   93   160        21  8032          365*
# 16  JB Hobbs (ENG)  1908-1930   61   102         7  5410           211
# 54   V Kohli (IND)  2011-2023  111   187        11  8676          254*
#
#     Averages Balls Faced Strike Rate  100  50   0    4s   6s
# 12     57.78       4063+       53.58   26  30  12  593+  32+
# 16     56.94       5363+       46.22   15  28   4  276+    8
# 54     49.29       15708       55.23   29  29  14   966   24

# %%
df[df['Player'].isin(['GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])]
# Out:
#             Player       Span  Mat  Inns  Not Outs  Runs Highest Score  \
# 11  GS Sobers (WI)  1954-1974   93   160        21  8032          365*
# 12  GS Sobers (WI)  1954-1974   93   160        21  8032          365*
# 15  JB Hobbs (ENG)  1908-1930   61   102         7  5410           211
# 16  JB Hobbs (ENG)  1908-1930   61   102         7  5410           211
# 53   V Kohli (IND)  2011-2023  111   187        11  8676          254*
# 54   V Kohli (IND)  2011-2023  111   187        11  8676          254*
#
#     Averages Balls Faced Strike Rate  100  50   0    4s   6s
# 11     57.78       4063+       53.58   26  30  12  593+  32+
# 12     57.78       4063+       53.58   26  30  12  593+  32+
# 15     56.94       5363+       46.22   15  28   4  276+    8
# 16     56.94       5363+       46.22   15  28   4  276+    8
# 53     49.29       15708       55.23   29  29  14   966   24
# 54     49.29       15708       55.23   29  29  14   966   24

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])]
# Out:
#             Player       Span  Mat  Inns  Not Outs  Runs Highest Score  \
# 11  GS Sobers (WI)  1954-1974   93   160        21  8032          365*
# 15  JB Hobbs (ENG)  1908-1930   61   102         7  5410           211
# 53   V Kohli (IND)  2011-2023  111   187        11  8676          254*
#
#     Averages Balls Faced Strike Rate  100  50   0    4s   6s
# 11     57.78       4063+       53.58   26  30  12  593+  32+
# 15     56.94       5363+       46.22   15  28   4  276+    8
# 53     49.29       15708       55.23   29  29  14   966   24

# %%
# Split the span into start date and end date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 62    [1965, 1981]
# 63    [2002, 2014]
# 64    [1924, 1934]
# 65    [1930, 1938]
# 66    [1928, 1934]
# Name: Span, Length: 64, dtype: object

# %%
df['Rookie Year'] = df['Span'].str.split(pat = '-').str[0]
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_8508\3061461579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Last Year'] = df['Span'].str.split(pat = '-').str[1]
# Out:
# C:\Users\Nikhil\AppData\Local\Temp\ipykernel_8508\1956753119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not Outs  Runs Highest Score  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996           334
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181           186
# 2      AC Voges (AUS)  2015-2016   20    31         7  1485          269*
# 3     RG Pollock (SA)  1963-1970   23    41         4  2256           274
# 4     GA Headley (WI)  1930-1954   22    40         4  2190          270*
# ..                ...        ...  ...   ...       ...   ...           ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357           250
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265           277
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122           266
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748           232
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296           127
#
#     Averages Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year  \
# ...

# %%
# delete column span

# %%
df.drop(['Span'], axis = 1)
# Out:
#                Player  Mat  Inns  Not Outs  Runs Highest Score  Averages  \
# 0    DG Bradman (AUS)   52    80        10  6996           334     99.94
# 1      HC Brook (ENG)   12    20         1  1181           186     62.15
# 2      AC Voges (AUS)   20    31         7  1485          269*     61.87
# 3     RG Pollock (SA)   23    41         4  2256           274     60.97
# 4     GA Headley (WI)   22    40         4  2190          270*     60.83
# ..                ...  ...   ...       ...   ...           ...       ...
# 62   KD Walters (AUS)   74   125        14  5357           250     48.26
# 63  GC Smith (ICC/SA)  117   205        13  9265           277     48.25
# 64  WH Ponsford (AUS)   29    48         4  2122           266     48.22
# 65    SJ McCabe (AUS)   39    62         5  2748           232     48.21
# 66   DR Jardine (ENG)   22    33         6  1296           127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year
# ...

# %%
df = df.drop(['Span'], axis = 1)

# %%
df
# Out:
#                Player  Mat  Inns  Not Outs  Runs Highest Score  Averages  \
# 0    DG Bradman (AUS)   52    80        10  6996           334     99.94
# 1      HC Brook (ENG)   12    20         1  1181           186     62.15
# 2      AC Voges (AUS)   20    31         7  1485          269*     61.87
# 3     RG Pollock (SA)   23    41         4  2256           274     60.97
# 4     GA Headley (WI)   22    40         4  2190          270*     60.83
# ..                ...  ...   ...       ...   ...           ...       ...
# 62   KD Walters (AUS)   74   125        14  5357           250     48.26
# 63  GC Smith (ICC/SA)  117   205        13  9265           277     48.25
# 64  WH Ponsford (AUS)   29    48         4  2122           266     48.22
# 65    SJ McCabe (AUS)   39    62         5  2748           232     48.21
# 66   DR Jardine (ENG)   22    33         6  1296           127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year
# ...

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 62     [KD Walters , AUS)]
# 63    [GC Smith , ICC/SA)]
# 64    [WH Ponsford , AUS)]
# 65      [SJ McCabe , AUS)]
# 66     [DR Jardine , ENG)]
# Name: Player, Length: 64, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df
# Out:
#                Player  Mat  Inns  Not Outs  Runs Highest Score  Averages  \
# 0    DG Bradman (AUS)   52    80        10  6996           334     99.94
# 1      HC Brook (ENG)   12    20         1  1181           186     62.15
# 2      AC Voges (AUS)   20    31         7  1485          269*     61.87
# 3     RG Pollock (SA)   23    41         4  2256           274     60.97
# 4     GA Headley (WI)   22    40         4  2190          270*     60.83
# ..                ...  ...   ...       ...   ...           ...       ...
# 62   KD Walters (AUS)   74   125        14  5357           250     48.26
# 63  GC Smith (ICC/SA)  117   205        13  9265           277     48.25
# 64  WH Ponsford (AUS)   29    48         4  2122           266     48.22
# 65    SJ McCabe (AUS)   39    62         5  2748           232     48.21
# 66   DR Jardine (ENG)   22    33         6  1296           127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# ...

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df
# Out:
#                Player  Mat  Inns  Not Outs  Runs Highest Score  Averages  \
# 0    DG Bradman (AUS)   52    80        10  6996           334     99.94
# 1      HC Brook (ENG)   12    20         1  1181           186     62.15
# 2      AC Voges (AUS)   20    31         7  1485          269*     61.87
# 3     RG Pollock (SA)   23    41         4  2256           274     60.97
# 4     GA Headley (WI)   22    40         4  2190          270*     60.83
# ..                ...  ...   ...       ...   ...           ...       ...
# 62   KD Walters (AUS)   74   125        14  5357           250     48.26
# 63  GC Smith (ICC/SA)  117   205        13  9265           277     48.25
# 64  WH Ponsford (AUS)   29    48         4  2122           266     48.22
# 65    SJ McCabe (AUS)   39    62         5  2748           232     48.21
# 66   DR Jardine (ENG)   22    33         6  1296           127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# ...

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996           334     99.94
# 1      HC Brook    12    20         1  1181           186     62.15
# 2      AC Voges    20    31         7  1485          269*     61.87
# 3    RG Pollock    23    41         4  2256           274     60.97
# 4    GA Headley    22    40         4  2190          270*     60.83
# ..           ...  ...   ...       ...   ...           ...       ...
# 62   KD Walters    74   125        14  5357           250     48.26
# 63     GC Smith   117   205        13  9265           277     48.25
# 64  WH Ponsford    29    48         4  2122           266     48.22
# 65    SJ McCabe    39    62         5  2748           232     48.21
# 66   DR Jardine    22    33         6  1296           127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# 0        9800+        58.6   29  13   7  626+   6        1928      1948
# ...

# %%
df['Highest Score'] = df['Highest Score'].str.split(pat = '*').str[0]

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996           334     99.94
# 1      HC Brook    12    20         1  1181           186     62.15
# 2      AC Voges    20    31         7  1485           269     61.87
# 3    RG Pollock    23    41         4  2256           274     60.97
# 4    GA Headley    22    40         4  2190           270     60.83
# ..           ...  ...   ...       ...   ...           ...       ...
# 62   KD Walters    74   125        14  5357           250     48.26
# 63     GC Smith   117   205        13  9265           277     48.25
# 64  WH Ponsford    29    48         4  2122           266     48.22
# 65    SJ McCabe    39    62         5  2748           232     48.21
# 66   DR Jardine    22    33         6  1296           127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# 0        9800+        58.6   29  13   7  626+   6        1928      1948
# ...

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not Outs           int64
# Runs               int64
# Highest Score     object
# Averages         float64
# Balls Faced       object
# Strike Rate       object
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# Rookie Year       object
# Last Year         object
# Country           object
# dtype: object

# %%
df['Highest Score'] = df['Highest Score'].astype('int')

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not Outs           int64
# Runs               int64
# Highest Score      int32
# Averages         float64
# Balls Faced       object
# Strike Rate       object
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# Rookie Year       object
# Last Year         object
# Country           object
# dtype: object

# %%
df['Balls Faced'] = df['Balls Faced'].str.split(pat = '+').str[0]

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# ...

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not Outs           int64
# Runs               int64
# Highest Score      int32
# Averages         float64
# Balls Faced       object
# Strike Rate       object
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# Rookie Year       object
# Last Year         object
# Country           object
# dtype: object

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# ...

# %%
df['Balls Faced'] = df['Balls Faced'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df['Balls Faced'] = df['Balls Faced'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
df.isnull().any()
# Out:
# Player           False
# Mat              False
# Inns             False
# Not Outs         False
# Runs             False
# Highest Score    False
# Averages         False
# Balls Faced       True
# Strike Rate      False
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# Rookie Year      False
# Last Year        False
# Country          False
# dtype: bool

# %%
df[df['Balls Faced'].isna()==1]
# Out:
#          Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 8    ED Weekes    48    81         5  4455            207     58.61
# 17  CL Walcott    44    74         7  3798            220     56.68
#
#    Balls Faced Strike Rate  100  50  0    4s  6s Rookie Year Last Year Country
# 8          NaN           0   15  19  6  258+   2        1948      1958      WI
# 17         NaN           0   15  14  1  107+  11        1948      1960      WI

# %%
df['Balls Faced'] = df['Balls Faced'].fillna(0)

# %%
df.isnull().any()
# Out:
# Player           False
# Mat              False
# Inns             False
# Not Outs         False
# Runs             False
# Highest Score    False
# Averages         False
# Balls Faced      False
# Strike Rate      False
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# Rookie Year      False
# Last Year        False
# Country          False
# dtype: bool

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not Outs           int64
# Runs               int64
# Highest Score      int32
# Averages         float64
# Balls Faced       object
# Strike Rate       object
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# Rookie Year       object
# Last Year         object
# Country           object
# dtype: object

# %%
df['Balls Faced'] = df['Balls Faced'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df['Balls Faced'] = df['Balls Faced'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
df.loc[56]
# Out:
# Player           MJ Clarke
# Mat                     115
# Inns                    198
# Not Outs                 22
# Runs                   8643
# Highest Score           329
# Averages               49.1
# Balls Faced           15456
# Strike Rate           55.92
# 100                      28
# 50                       27
# 0                         9
# 4s                      978
# 6s                       39
# Rookie Year            2004
# Last Year              2015
# Country                 AUS
# Name: 56, dtype: object

# %%
df['Balls Faced'] = df['Balls Faced'].str.split(pat = '-').str[0]

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# ...

# %%
df['Balls Faced'] = df['Balls Faced'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df['Balls Faced'] = df['Balls Faced'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
df[df['Balls Faced'].isna()==1]
# Out:
#          Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 8    ED Weekes    48    81         5  4455            207     58.61
# 17  CL Walcott    44    74         7  3798            220     56.68
#
#    Balls Faced Strike Rate  100  50  0    4s  6s Rookie Year Last Year Country
# 8          NaN           0   15  19  6  258+   2        1948      1958      WI
# 17         NaN           0   15  14  1  107+  11        1948      1960      WI

# %%
df['Balls Faced'] = df['Balls Faced'].fillna(0)

# %%
df.isnull().any()
# Out:
# Player           False
# Mat              False
# Inns             False
# Not Outs         False
# Runs             False
# Highest Score    False
# Averages         False
# Balls Faced      False
# Strike Rate      False
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# Rookie Year      False
# Last Year        False
# Country          False
# dtype: bool

# %%
df['Balls Faced'] = df['Balls Faced'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df['Balls Faced'] = df['Balls Faced'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
df.loc[59]
# Out:
# Player           Hon.FS Jackson
# Mat                           20
# Inns                          33
# Not Outs                       4
# Runs                        1415
# Highest Score                144
# Averages                   48.79
# Balls Faced
# Strike Rate                    -
# 100                            5
# 50                             6
# 0                              3
# 4s                           51+
# 6s                             0
# Rookie Year                 1893
# Last Year                   1905
# Country                      ENG
# Name: 59, dtype: object

# %%
df = df.drop(59, axis = 0)

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#    Balls Faced Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# ...

# %%
df['Balls Faced'] = df['Balls Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not Outs           int64
# Runs               int64
# Highest Score      int32
# Averages         float64
# Balls Faced        int32
# Strike Rate       object
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# Rookie Year       object
# Last Year         object
# Country           object
# dtype: object

# %%
df['Strike Rate'] = df['Strike Rate'].astype('float')

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not Outs           int64
# Runs               int64
# Highest Score      int32
# Averages         float64
# Balls Faced        int32
# Strike Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# Rookie Year       object
# Last Year         object
# Country           object
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#     Balls Faced  Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# ...

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#     Balls Faced  Strike Rate  100  50   0    4s  6s Rookie Year Last Year  \
# ...

# %%
#Question 1 --> What is the average career leangth

# %%
df['career_length'] = df['Last Year'] - df['Rookie Year']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# ...

# %%
df['Last Year'] = df['Last Year'].astype('int')

# %%
df['Rookie Year'] = df['Rookie Year'].astype('int')

# %%
df.dtypes
# Out:
# Player            object
# Mat                int64
# Inns               int64
# Not Outs           int64
# Runs               int64
# Highest Score      int32
# Averages         float64
# Balls Faced        int32
# Strike Rate      float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# Rookie Year        int32
# Last Year          int32
# Country           object
# dtype: object

# %%
df['career_length'] = df['Last Year'] - df['Rookie Year']

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#     Balls Faced  Strike Rate  100  50   0    4s  6s  Rookie Year  Last Year  \
# ...

# %%
#Question 1 --> What is the average career leangth

# %%
df['career_length'].mean()
# Out:
# 12.761904761904763

# %%
# Question 2 --> Average batting strike rate for cricketers who played over 10 years

# %%
df[df['career_length'] > 10]['Strike Rate'].mean()
# Out:
# 49.06976744186046

# %%
#Question 3 --> Number of cricketers player before 1960

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#     Balls Faced  Strike Rate  100  50   0    4s  6s  Rookie Year  Last Year  \
# ...

# %%
df[df['Rookie Year'] < 1960]['Player'].count()
# Out:
# 22

# %%
# Question 4 --> Max highest innings score by country

# %%
df
# Out:
#           Player  Mat  Inns  Not Outs  Runs  Highest Score  Averages  \
# 0    DG Bradman    52    80        10  6996            334     99.94
# 1      HC Brook    12    20         1  1181            186     62.15
# 2      AC Voges    20    31         7  1485            269     61.87
# 3    RG Pollock    23    41         4  2256            274     60.97
# 4    GA Headley    22    40         4  2190            270     60.83
# ..           ...  ...   ...       ...   ...            ...       ...
# 62   KD Walters    74   125        14  5357            250     48.26
# 63     GC Smith   117   205        13  9265            277     48.25
# 64  WH Ponsford    29    48         4  2122            266     48.22
# 65    SJ McCabe    39    62         5  2748            232     48.21
# 66   DR Jardine    22    33         6  1296            127     48.00
#
#     Balls Faced  Strike Rate  100  50   0    4s  6s  Rookie Year  Last Year  \
# ...

# %%
df.groupby('Country')['Highest Score'].max().sort_values(ascending = False)
# Out:
# Country
# ICC/WI     400
# AUS        380
# SL         374
# WI         365
# ENG        364
# ICC/PAK    329
# ICC/IND    319
# PAK        313
# SA         278
# ICC/SA     277
# IND        254
# NZ         251
# ZIM        232
# Name: Highest Score, dtype: int32
